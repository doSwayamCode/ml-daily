# %% [markdown]
# # Representation and data visualization

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: C:\Users\Swayam\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X_data = np.random.random(50) * 100
Y_data = np.random.random(50) * 100

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(X_data, Y_data, color='red', alpha=0.5, edgecolor='black')

# %%
plt.scatter(X_data, Y_data, color='red')

# %%
years =[2006 + x for x in range(16)]

# %%
years
# Out:
# [2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
weights = [80, 82, 85, 88, 90, 92, 95, 98, 100, 102, 105, 17, 10, 12, 15, 11]

# %%
plt.plot(years, weights)

# %%
plt.scatter(years, weights)

# %%
plt.scatter(years, weights, c='blue', s=weights, alpha=0.5, edgecolor='black')

# %%
plt.scatter(years, weights, linestyle='--')

# %%
x= ["C++", "Python", "Java", "JavaScript", "Ruby", "PHP"]
y= [20, 30, 25, 35, 15, 10]

plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(x,y, color = 'green', align = "edge")
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(x,y, color = 'green', align = "edge", edgecolor = 'black', linewidth = 2)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(x,y, color = 'green', align = "edge", edgecolor = 'black', lw=6)
# Out:
# <BarContainer object of 6 artists>

# %%
age =np.random.normal(20, 1.5, 1000)
# here 20 is the mean and 1.5 is the standard deviation

# %%
age
# Out:
# array([19.50097549, 21.6788412 , 18.36384932, 20.9556017 , 22.03817429,
#        21.05344636, 19.69583204, 20.11347032, 18.30833752, 20.38279547,
#        18.88336323, 20.29945023, 19.96758009, 20.87777194, 19.64575559,
#        21.47162157, 19.72539471, 20.50275217, 21.42757154, 18.81870342,
#        16.38499817, 20.12070654, 20.46730904, 20.92040867, 18.86365222,
#        20.21077466, 20.81196378, 19.48707911, 21.39994355, 20.27630365,
#        18.55461759, 19.85878867, 17.38752019, 22.00980739, 21.81032738,
#        17.77553093, 22.71930475, 19.381755  , 20.57471978, 20.43278356,
#        19.53657335, 20.87632285, 18.59642852, 21.99714272, 19.06174141,
#        21.3195078 , 21.48717882, 21.13507009, 18.2122574 , 21.55011786,
#        21.55337334, 19.80677992, 19.75142505, 21.28634383, 19.15106962,
#        16.77614833, 18.64232191, 22.43172581, 19.69850063, 19.01514143,
#        22.96797937, 17.74698955, 22.05167517, 21.06413598, 19.6164468 ,
# ...

# %%
plt.hist(age)
# Out:
# (array([  6.,  28.,  94., 155., 237., 234., 160.,  59.,  20.,   7.]),
#  array([15.42548962, 16.36818012, 17.31087061, 18.2535611 , 19.19625159,
#         20.13894208, 21.08163257, 22.02432307, 22.96701356, 23.90970405,
#         24.85239454]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(age, bins =30)
# Out:
# (array([ 1.,  4.,  1.,  8.,  5., 15., 19., 34., 41., 45., 56., 54., 79.,
#         83., 75., 86., 78., 70., 61., 57., 42., 25., 16., 18.,  9.,  6.,
#          5.,  4.,  1.,  2.]),
#  array([15.42548962, 15.73971979, 16.05394995, 16.36818012, 16.68241028,
#         16.99664044, 17.31087061, 17.62510077, 17.93933093, 18.2535611 ,
#         18.56779126, 18.88202143, 19.19625159, 19.51048175, 19.82471192,
#         20.13894208, 20.45317225, 20.76740241, 21.08163257, 21.39586274,
#         21.7100929 , 22.02432307, 22.33855323, 22.65278339, 22.96701356,
#         23.28124372, 23.59547388, 23.90970405, 24.22393421, 24.53816438,
#         24.85239454]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(age, bins =2)
# Out:
# (array([520., 480.]),
#  array([15.42548962, 20.13894208, 24.85239454]),
#  <BarContainer object of 2 artists>)

# %%
plt.hist(age, bins=5)
# Out:
# (array([ 34., 249., 471., 219.,  27.]),
#  array([15.42548962, 17.31087061, 19.19625159, 21.08163257, 22.96701356,
#         24.85239454]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(age, bins =[age.min(), 18, 20, 22, age.max()])
# Out:
# (array([ 97., 393., 420.,  90.]),
#  array([15.42548962, 18.        , 20.        , 22.        , 24.85239454]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(age, bins=5, cumulative=True)
# Out:
# (array([  34.,  283.,  754.,  973., 1000.]),
#  array([15.42548962, 17.31087061, 19.19625159, 21.08163257, 22.96701356,
#         24.85239454]),
#  <BarContainer object of 5 artists>)

# %%
langs = ["C++", "Python", "Java", "JavaScript", "Ruby", "PHP"]
votes = [20, 30, 25, 35, 15, 10]

plt.pie(votes, labels=langs)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c82cc30f90>,
# ...
#  [Text(0.9829959012313648, 0.49367910444167784, 'C++'),
#   Text(-0.06395956521576165, 1.0981389593386672, 'Python'),
#   Text(-1.0703494319334557, 0.25367714433848587, 'Java'),
#   Text(-0.4356874878546271, -1.0100378274732706, 'JavaScript'),
#   Text(0.7548659446125069, -0.8001108708574505, 'Ruby'),
#   Text(1.0703494541106127, -0.25367705076556196, 'PHP')])

# %%
explode = [0.1, 0, 0, 0, 0, 0]
plt.pie(votes, labels=langs, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c82cca0190>,
# ...
#  [Text(1.0723591649796707, 0.5385590230272849, 'C++'),
#   Text(-0.06395956521576165, 1.0981389593386672, 'Python'),
#   Text(-1.0703494319334557, 0.25367714433848587, 'Java'),
#   Text(-0.4356874878546271, -1.0100378274732706, 'JavaScript'),
#   Text(0.7548659446125069, -0.8001108708574505, 'Ruby'),
#   Text(1.0703494541106127, -0.25367705076556196, 'PHP')])

# %%
plt.pie(votes, labels=langs, explode=explode, autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2c82ccec110>,
# ...
#  [Text(1.0723591649796707, 0.5385590230272849, 'C++'),
#   Text(-0.06395956521576165, 1.0981389593386672, 'Python'),
#   Text(-1.0703494319334557, 0.25367714433848587, 'Java'),
#   Text(-0.4356874878546271, -1.0100378274732706, 'JavaScript'),
#   Text(0.7548659446125069, -0.8001108708574505, 'Ruby'),
#   Text(1.0703494541106127, -0.25367705076556196, 'PHP')],
#  [Text(0.6255428462381412, 0.3141594300992495, '14.81%'),
#   Text(-0.034887035572233625, 0.5989848869120002, '22.22%'),
#   Text(-0.5838269628727939, 0.1383693514573559, '18.52%'),
#   Text(-0.23764772064797837, -0.5509297240763293, '25.93%'),
#   Text(0.41174506069773104, -0.4364241113767911, '11.11%'),
#   Text(0.583826974969425, -0.13836930041757922, '7.41%')])

# %%
plt.pie(votes, labels=langs, explode=explode, autopct='%.2f%%', pctdistance=0.85)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c82cd3d250>,
# ...
#  [Text(1.0723591649796707, 0.5385590230272849, 'C++'),
#   Text(-0.06395956521576165, 1.0981389593386672, 'Python'),
#   Text(-1.0703494319334557, 0.25367714433848587, 'Java'),
#   Text(-0.4356874878546271, -1.0100378274732706, 'JavaScript'),
#   Text(0.7548659446125069, -0.8001108708574505, 'Ruby'),
#   Text(1.0703494541106127, -0.25367705076556196, 'PHP')],
#  [Text(0.848951005608906, 0.4263592265632672, '14.81%'),
#   Text(-0.049423300393997636, 0.8485619231253336, '22.22%'),
#   Text(-0.8270881974031247, 0.19602324789792086, '18.52%'),
#   Text(-0.3366676042513027, -0.7804837757747999, '25.93%'),
#   Text(0.5833055026551189, -0.6182674911171208, '11.11%'),
#   Text(0.8270882145400188, -0.1960231755915706, '7.41%')])

# %%
plt.pie(votes, labels=langs, explode=explode, autopct='%.2f%%', pctdistance=1.4)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c82cd95a50>,
# ...
#  [Text(1.0723591649796707, 0.5385590230272849, 'C++'),
#   Text(-0.06395956521576165, 1.0981389593386672, 'Python'),
#   Text(-1.0703494319334557, 0.25367714433848587, 'Java'),
#   Text(-0.4356874878546271, -1.0100378274732706, 'JavaScript'),
#   Text(0.7548659446125069, -0.8001108708574505, 'Ruby'),
#   Text(1.0703494541106127, -0.25367705076556196, 'PHP')],
#  [Text(1.3404489562245883, 0.673198778784106, '14.81%'),
#   Text(-0.08140308300187846, 1.3976314027946672, '22.22%'),
#   Text(-1.3622629133698525, 0.3228618200671638, '18.52%'),
#   Text(-0.5545113481786161, -1.2855026895114352, '25.93%'),
#   Text(0.9607384749613723, -1.0183229265458458, '11.11%'),
#   Text(1.3622629415953251, -0.3228617009743515, '7.41%')])

# %%
plt.pie(votes, labels=langs, explode=explode, autopct='%.2f%%', pctdistance=1.4, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c82cde6890>,
# ...
#  [Text(-0.5385592616543425, 1.072359045136623, 'C++'),
#   Text(-1.0981389641674768, -0.06395948230857662, 'Python'),
#   Text(-0.25367722514761903, -1.070349412781361, 'Java'),
#   Text(1.0100378984557588, -0.43568732329857207, 'JavaScript'),
#   Text(0.8001107478741672, 0.7548660749671038, 'Ruby'),
#   Text(0.2536768763834982, 1.070349495439836, 'PHP')],
#  [Text(-0.673199077067928, 1.3404488064207785, '14.81%'),
#   Text(-1.397631408940425, -0.08140297748364296, '22.22%'),
#   Text(-0.3228619229151514, -1.3622628889944592, '18.52%'),
#   Text(1.2855027798527836, -0.5545111387436371, '25.93%'),
#   Text(1.0183227700216673, 0.9607386408672228, '11.11%'),
#   Text(0.32286147903354306, 1.3622629941961548, '7.41%')])

# %%
heights = np.random.normal(172, 8, 300)
heights
# Out:
# array([169.5209314 , 172.65043893, 164.14888567, 150.75925124,
#        162.05862893, 181.8766995 , 186.6840954 , 179.58377978,
#        173.89392496, 163.92066116, 174.01329556, 178.51616014,
#        175.53609979, 171.70698102, 173.3432067 , 176.3656343 ,
#        166.69420767, 165.25755787, 180.97724063, 169.72971301,
#        156.15853769, 175.15401584, 171.5808433 , 165.00777475,
#        169.15654164, 181.42629732, 171.06237036, 187.06450012,
#        163.05054318, 181.86035234, 174.29834069, 165.55316673,
#        164.83824943, 180.21214864, 172.57509345, 173.21331768,
#        164.90839038, 183.9807919 , 165.09985742, 172.45223479,
#        165.82530665, 166.00082302, 176.83169109, 171.0262097 ,
#        173.18925465, 162.0622375 , 170.54994479, 175.16375914,
#        178.29410807, 163.94005808, 180.46089039, 172.40163   ,
#        171.34261742, 169.73746333, 188.40397508, 173.98923217,
#        170.85348645, 180.53338819, 178.15823624, 176.58668239,
# ...

# %%
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c82ce3fa50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c82ce551d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c82c945550>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c82ce568d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c82ce57350>],
#  'means': []}

# %%
first = np.linspace(0,10,25)
second = np.linspace(10,200,25)
third = np.linspace(200,210,25)
fourth = np.linspace(210,230,25)

# %%
data= np.concatenate((first, second, third, fourth))

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c82cea3f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c82ceb1710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c82ce2dcd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c82ceb2c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c82ceb36d0>],
#  'means': []}

# %% [markdown]
# ## Customization of Axes

# %%
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

income = [55, 56,62,61,72,72,73,75]

income_ticks = list(range(50, 81, 2))

# %%
plt.plot(years, income)
plt.title("Income per year")
plt.xlabel("Year")
plt.ylabel("Income in thousands",fontsize=12, fontname='Arial')
plt.yticks(income_ticks, [f"{x}k USD" for x in income_ticks])
# Out:
# ([<matplotlib.axis.YTick at 0x2c82f3e5710>,
# ...
#  [Text(0, 50, '50k USD'),
#   Text(0, 52, '52k USD'),
#   Text(0, 54, '54k USD'),
#   Text(0, 56, '56k USD'),
#   Text(0, 58, '58k USD'),
#   Text(0, 60, '60k USD'),
#   Text(0, 62, '62k USD'),
#   Text(0, 64, '64k USD'),
#   Text(0, 66, '66k USD'),
#   Text(0, 68, '68k USD'),
#   Text(0, 70, '70k USD'),
#   Text(0, 72, '72k USD'),
#   Text(0, 74, '74k USD'),
#   Text(0, 76, '76k USD'),
#   Text(0, 78, '78k USD'),
#   Text(0, 80, '80k USD')])

# %%
stock_a = [100, 102, 105, 107, 110, 108, 111, 115]
stock_b = [100, 98, 97, 95, 96, 94, 93, 92]
stock_c = [100, 101, 103, 102, 104, 105, 200, 108]

plt.plot(stock_a, label='Stock A')
plt.plot(stock_b, label='Stock B')
plt.plot(stock_c, label='Stock C')

plt.legend(loc ='lower left')

# %%
stock_a = [100, 102, 105, 107, 110, 108, 111, 115]
stock_b = [100, 98, 97, 95, 96, 94, 93, 92]
stock_c = [100, 101, 103, 102, 104, 105, 200, 108]

plt.plot(stock_a, label='Stock A')
plt.plot(stock_b, label='Stock B')
plt.plot(stock_c, label='Stock C')

plt.legend(loc ='upper left')

# %%
votes = [20, 30, 25, 35, 15, 10]
people = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank"]

plt.pie(votes, labels =None)
plt.legend(labels =people)

# %% [markdown]
# ## Stylesheets

# %%
from matplotlib import style

# %%
votes = [20, 30, 25, 35, 15, 10]
people = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank"]

plt.pie(votes, labels =None)
plt.legend(labels =people)

style.use('ggplot')

# %%
votes = [20, 30, 25, 35, 15, 10]
people = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank"]

plt.pie(votes, labels =None)
plt.legend(labels =people)

style.use('dark_background')

# %%
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.random.random(100), np.random.random(100)


plt.figure(1)
plt.scatter(x1, y1)

plt.figure(2)
plt.plot(x2, y2)

# %%
x= np.arange(100)

fig, axs= plt.subplots(2, 2)

axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title('Sine Wave')

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title('Cosine Wave')

axs[1,0].plot(x, np.random.random(100))
axs[0,1].set_title('Random Wave')

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title('Log Wave')
# Out:
# C:\Users\Swayam\AppData\Local\Temp\ipykernel_2748\578943992.py:14: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))
# Text(0.5, 1.0, 'Log Wave')

# %%
x= np.arange(100)

fig, axs= plt.subplots(2, 2)

axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title('Sine Wave')

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title('Cosine Wave')

axs[1,0].plot(x, np.random.random(100))
axs[0,1].set_title('Random Wave')

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title('Log Wave')


fig.suptitle('four plots')
# Out:
# C:\Users\Swayam\AppData\Local\Temp\ipykernel_2748\3028817807.py:14: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))
# Text(0.5, 0.98, 'four plots')

# %%
# how to export the plot

x= np.arange(100)

fig, axs= plt.subplots(2, 2)

axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title('Sine Wave')

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title('Cosine Wave')

axs[1,0].plot(x, np.random.random(100))
axs[0,1].set_title('Random Wave')

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title('Log Wave')


fig.suptitle('four plots')
plt.tight_layout()

plt.savefig('four_plots.png', dpi=300, bbox_inches='tight', transparent=True)
# Out:
# C:\Users\Swayam\AppData\Local\Temp\ipykernel_2748\2668404721.py:16: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))

# %% [markdown]
# ## 3D plotting and animations

# %%
ax = plt.axes(projection = "3d")

x= np.random.random(100)
y= np.random.random(100)
z= np.random.random(100)

ax.scatter(x, y, z, c='r', marker='o')
ax.set_title('3D Scatter Plot')
# Out:
# Text(0.5, 0.92, '3D Scatter Plot')

# %%
ax = plt.axes(projection = "3d")

x= np.arange(0,50,0.1)
y= np.sin(x)
z= np.cos(x)

ax.plot(x,y,z)

# %%
ax = plt.axes(projection = "3d")


x = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x, y)

Z= np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap='Spectral')
ax.view_init(azim=0, elev=90)

# %%
ax = plt.axes(projection = "3d")


x = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x, y)

Z= np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap='Spectral')

# %% [markdown]
# ## animations

# %%
import random

# %%
head_tails = [0,0]

for i in range(10):
    head_tails[random.randint(0,1)] += 1
    plt.bar(['Heads', 'Tails'], head_tails, color=['blue', 'red'])
    plt.pause(0.001)
