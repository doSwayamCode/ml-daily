# %% [markdown]
# <a href="https://colab.research.google.com/github/doSwayamCode/ml-daily/blob/main/pandas_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata_profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset (replace with your actual data source)
df = pd.read_csv('/content/train_and_test2.csv')

# Create and export profile report
prof = ProfileReport(df, title="Data Profiling Report")
prof.to_file("output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
