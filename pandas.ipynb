# %% [markdown]
# # Key data structures in Pandas
# * Series (1 Dimentional)
# * Dataframe (2 dimentional)

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({"names" : ["Swayam", "Vansh", "Dev", "Sonu", "Pushpa"], "marks": [100, 90, 95, 85, 80]})

# %%
df
# Out:
#     names  marks
# 0  Swayam    100
# 1   Vansh     90
# 2     Dev     95
# 3    Sonu     85
# 4  Pushpa     80

# %%
df = pd.read_csv("timezone.csv")

# %%
df
# Out:
#                   Value        Label           Group
# 0        Africa/Abidjan      Abidjan          Africa
# 1          Africa/Accra        Accra          Africa
# 2    Africa/Addis_Ababa  Addis Ababa          Africa
# 3        Africa/Algiers      Algiers          Africa
# 4         Africa/Asmara       Asmara          Africa
# ..                  ...          ...             ...
# 476              UTC+12       UTC+12  Manual Offsets
# 477           UTC+12.75    UTC+12:45  Manual Offsets
# 478              UTC+13       UTC+13  Manual Offsets
# 479           UTC+13.75    UTC+13:45  Manual Offsets
# 480              UTC+14       UTC+14  Manual Offsets
#
# [481 rows x 3 columns]

# %%
df.head()
# Out:
#                 Value        Label   Group
# 0      Africa/Abidjan      Abidjan  Africa
# 1        Africa/Accra        Accra  Africa
# 2  Africa/Addis_Ababa  Addis Ababa  Africa
# 3      Africa/Algiers      Algiers  Africa
# 4       Africa/Asmara       Asmara  Africa

# %%
df.tail()
# Out:
#          Value      Label           Group
# 476     UTC+12     UTC+12  Manual Offsets
# 477  UTC+12.75  UTC+12:45  Manual Offsets
# 478     UTC+13     UTC+13  Manual Offsets
# 479  UTC+13.75  UTC+13:45  Manual Offsets
# 480     UTC+14     UTC+14  Manual Offsets

# %%
df.describe()
# Out:
#          Value   Label    Group
# count      481     481      481
# unique     481     481       12
# top     UTC+14  UTC+14  America
# freq         1       1      147

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   481 non-null    object
#  1   Label   481 non-null    object
#  2   Group   481 non-null    object
# dtypes: object(3)
# memory usage: 11.4+ KB

# %% [markdown]
# # Data Selection

# %%
df["Value"]
# Out:
# 0          Africa/Abidjan
# 1            Africa/Accra
# 2      Africa/Addis_Ababa
# 3          Africa/Algiers
# 4           Africa/Asmara
#               ...
# 476                UTC+12
# 477             UTC+12.75
# 478                UTC+13
# 479             UTC+13.75
# 480                UTC+14
# Name: Value, Length: 481, dtype: object

# %%
type(df["Value"])
# Out:
# pandas.core.series.Series

# %%
df[["Value", "Label"]]
# Out:
#                   Value        Label
# 0        Africa/Abidjan      Abidjan
# 1          Africa/Accra        Accra
# 2    Africa/Addis_Ababa  Addis Ababa
# 3        Africa/Algiers      Algiers
# 4         Africa/Asmara       Asmara
# ..                  ...          ...
# 476              UTC+12       UTC+12
# 477           UTC+12.75    UTC+12:45
# 478              UTC+13       UTC+13
# 479           UTC+13.75    UTC+13:45
# 480              UTC+14       UTC+14
#
# [481 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Value    Africa/Abidjan
# Label           Abidjan
# Group            Africa
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# * df.dropna() will drop the rows having any missing value
# * df.fillna(0) saari value khali wali 0 se fill hojyegi
# * df.fillna(0, inplace = True) using inplace will change the real data values you do here

# %%
df
# Out:
#                   Value        Label           Group
# 0        Africa/Abidjan      Abidjan          Africa
# 1          Africa/Accra        Accra          Africa
# 2    Africa/Addis_Ababa  Addis Ababa          Africa
# 3        Africa/Algiers      Algiers          Africa
# 4         Africa/Asmara       Asmara          Africa
# ..                  ...          ...             ...
# 476              UTC+12       UTC+12  Manual Offsets
# 477           UTC+12.75    UTC+12:45  Manual Offsets
# 478              UTC+13       UTC+13  Manual Offsets
# 479           UTC+13.75    UTC+13:45  Manual Offsets
# 480              UTC+14       UTC+14  Manual Offsets
#
# [481 rows x 3 columns]

# %%
df.rename(columns={"Label" : "L"})
# Out:
#                   Value            L           Group
# 0        Africa/Abidjan      Abidjan          Africa
# 1          Africa/Accra        Accra          Africa
# 2    Africa/Addis_Ababa  Addis Ababa          Africa
# 3        Africa/Algiers      Algiers          Africa
# 4         Africa/Asmara       Asmara          Africa
# ..                  ...          ...             ...
# 476              UTC+12       UTC+12  Manual Offsets
# 477           UTC+12.75    UTC+12:45  Manual Offsets
# 478              UTC+13       UTC+13  Manual Offsets
# 479           UTC+13.75    UTC+13:45  Manual Offsets
# 480              UTC+14       UTC+14  Manual Offsets
#
# [481 rows x 3 columns]

# %%
df
# Out:
#                   Value        Label           Group
# 0        Africa/Abidjan      Abidjan          Africa
# 1          Africa/Accra        Accra          Africa
# 2    Africa/Addis_Ababa  Addis Ababa          Africa
# 3        Africa/Algiers      Algiers          Africa
# 4         Africa/Asmara       Asmara          Africa
# ..                  ...          ...             ...
# 476              UTC+12       UTC+12  Manual Offsets
# 477           UTC+12.75    UTC+12:45  Manual Offsets
# 478              UTC+13       UTC+13  Manual Offsets
# 479           UTC+13.75    UTC+13:45  Manual Offsets
# 480              UTC+14       UTC+14  Manual Offsets
#
# [481 rows x 3 columns]

# %%
df.describe()
# Out:
#          Value   Label    Group
# count      481     481      481
# unique     481     481       12
# top     UTC+14  UTC+14  America
# freq         1       1      147

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   481 non-null    object
#  1   Label   481 non-null    object
#  2   Group   481 non-null    object
# dtypes: object(3)
# memory usage: 11.4+ KB

# %%
len(df)
# Out:
# 481

# %%
df["zeros"] = [0 for i in range(len(df))]

# %%
df
# Out:
#                   Value        Label           Group  zeros
# 0        Africa/Abidjan      Abidjan          Africa      0
# 1          Africa/Accra        Accra          Africa      0
# 2    Africa/Addis_Ababa  Addis Ababa          Africa      0
# 3        Africa/Algiers      Algiers          Africa      0
# 4         Africa/Asmara       Asmara          Africa      0
# ..                  ...          ...             ...    ...
# 476              UTC+12       UTC+12  Manual Offsets      0
# 477           UTC+12.75    UTC+12:45  Manual Offsets      0
# 478              UTC+13       UTC+13  Manual Offsets      0
# 479           UTC+13.75    UTC+13:45  Manual Offsets      0
# 480              UTC+14       UTC+14  Manual Offsets      0
#
# [481 rows x 4 columns]

# %%
df['Label'] = df['Label'].astype(str)

# %%
df['Label'][0]
# Out:
# 'Abidjan'

# %%
df
# Out:
#                   Value        Label           Group  zeros
# 0        Africa/Abidjan      Abidjan          Africa      0
# 1          Africa/Accra        Accra          Africa      0
# 2    Africa/Addis_Ababa  Addis Ababa          Africa      0
# 3        Africa/Algiers      Algiers          Africa      0
# 4         Africa/Asmara       Asmara          Africa      0
# ..                  ...          ...             ...    ...
# 476              UTC+12       UTC+12  Manual Offsets      0
# 477           UTC+12.75    UTC+12:45  Manual Offsets      0
# 478              UTC+13       UTC+13  Manual Offsets      0
# 479           UTC+13.75    UTC+13:45  Manual Offsets      0
# 480              UTC+14       UTC+14  Manual Offsets      0
#
# [481 rows x 4 columns]

# %%
len(df)
# Out:
# 481

# %%
df
# Out:
#                   Value        Label           Group  zeros
# 0        Africa/Abidjan      Abidjan          Africa      0
# 1          Africa/Accra        Accra          Africa      0
# 2    Africa/Addis_Ababa  Addis Ababa          Africa      0
# 3        Africa/Algiers      Algiers          Africa      0
# 4         Africa/Asmara       Asmara          Africa      0
# ..                  ...          ...             ...    ...
# 476              UTC+12       UTC+12  Manual Offsets      0
# 477           UTC+12.75    UTC+12:45  Manual Offsets      0
# 478              UTC+13       UTC+13  Manual Offsets      0
# 479           UTC+13.75    UTC+13:45  Manual Offsets      0
# 480              UTC+14       UTC+14  Manual Offsets      0
#
# [481 rows x 4 columns]

# %%
def fx(a):
    return a * a
df["zeros + 1"] = df["zeros"] .apply(fx)

# %%
df
# Out:
#                   Value        Label           Group  zeros  zeros + 1
# 0        Africa/Abidjan      Abidjan          Africa      0          0
# 1          Africa/Accra        Accra          Africa      0          0
# 2    Africa/Addis_Ababa  Addis Ababa          Africa      0          0
# 3        Africa/Algiers      Algiers          Africa      0          0
# 4         Africa/Asmara       Asmara          Africa      0          0
# ..                  ...          ...             ...    ...        ...
# 476              UTC+12       UTC+12  Manual Offsets      0          0
# 477           UTC+12.75    UTC+12:45  Manual Offsets      0          0
# 478              UTC+13       UTC+13  Manual Offsets      0          0
# 479           UTC+13.75    UTC+13:45  Manual Offsets      0          0
# 480              UTC+14       UTC+14  Manual Offsets      0          0
#
# [481 rows x 5 columns]

# %%
df.to_csv("timezoneExportNew.csv" ,index=False)

# %%
df1= pd.DataFrame({
    "names" : ["Swayam", "Vansh", "Dev", "Sonu", "Pushpa"], 
    "marks": [100, 90, 95, 85, 80],
})

# %%
df1
# Out:
#     names  marks
# 0  Swayam    100
# 1   Vansh     90
# 2     Dev     95
# 3    Sonu     85
# 4  Pushpa     80

# %%
df2= pd.DataFrame({
    "name" : ["Hitesh", "Harry", "Piyush", "Striver", "Mannu", "Akshay Saini"],
    "marks": [100, 90, 95, 85, 80, 100],
})

# %%
df2
# Out:
#            name  marks
# 0        Hitesh    100
# 1         Harry     90
# 2        Piyush     95
# 3       Striver     85
# 4         Mannu     80
# 5  Akshay Saini    100

# %%
pd.concat([df1, df2])
# Out:
#     names  marks          name
# 0  Swayam    100           NaN
# 1   Vansh     90           NaN
# 2     Dev     95           NaN
# 3    Sonu     85           NaN
# 4  Pushpa     80           NaN
# 0     NaN    100        Hitesh
# 1     NaN     90         Harry
# 2     NaN     95        Piyush
# 3     NaN     85       Striver
# 4     NaN     80         Mannu
# 5     NaN    100  Akshay Saini

# %% [markdown]
# * pd.merge() skips the value in dataframe jiski dono dataframe me value nhi hai.

# %%
pd.merge(df1,df2, on ="marks")
# Out:
#     names  marks          name
# 0  Swayam    100        Hitesh
# 1  Swayam    100  Akshay Saini
# 2   Vansh     90         Harry
# 3     Dev     95        Piyush
# 4    Sonu     85       Striver
# 5  Pushpa     80         Mannu
